# %%
#Selenium 사용

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('../driver/chromedriver')
driver.get("https://naver.com")

# %%
driver.save_screenshot('../images/001.jpg')
# Out:
# True

# %%
xpath = """//*[@id="account"]/div/a"""
driver.find_element_by_xpath(xpath).click()

# %%
elem_login = driver.find_element_by_id("id")
elem_login.clear()
elem_login.send_keys("tnckd9586")

elem_login = driver.find_element_by_id("pw")
elem_login.clear()
elem_login.send_keys("rla2013104580!")

# %%
xpath = """//*[@id="frmNIDLogin"]/fieldset/input"""
driver.find_element_by_xpath(xpath).click()

# %%
driver.close()

# %%
#서울시 구별 주유소 가격 정보 얻기

# %%
driver = webdriver.Chrome('../driver/chromedriver')
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name("option")

# %%
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id("SIGUNGU_NM0")
element.send_keys(gu_names[0])

# %%
xpath = """//*[@id="searRgSelect"]"""
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = """//*[@id="glopopd_excel"]"""
element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
import time
from tqdm import tqdm_notebook

for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    time.sleep(2)
    
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(2)
    
    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
driver.close()

# %%
import pandas as pd
from glob import glob

# %%
glob('../data/지역*.xls')
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
station_files = glob("../data/지역*.xls")
station_files
# Out:
# ['../data\\지역_위치별(주유소) (1).xls',
#  '../data\\지역_위치별(주유소) (10).xls',
#  '../data\\지역_위치별(주유소) (11).xls',
#  '../data\\지역_위치별(주유소) (12).xls',
#  '../data\\지역_위치별(주유소) (13).xls',
#  '../data\\지역_위치별(주유소) (14).xls',
#  '../data\\지역_위치별(주유소) (15).xls',
#  '../data\\지역_위치별(주유소) (16).xls',
#  '../data\\지역_위치별(주유소) (17).xls',
#  '../data\\지역_위치별(주유소) (18).xls',
#  '../data\\지역_위치별(주유소) (19).xls',
#  '../data\\지역_위치별(주유소) (2).xls',
#  '../data\\지역_위치별(주유소) (20).xls',
#  '../data\\지역_위치별(주유소) (21).xls',
#  '../data\\지역_위치별(주유소) (22).xls',
#  '../data\\지역_위치별(주유소) (23).xls',
#  '../data\\지역_위치별(주유소) (24).xls',
#  '../data\\지역_위치별(주유소) (3).xls',
#  '../data\\지역_위치별(주유소) (4).xls',
#  '../data\\지역_위치별(주유소) (5).xls',
#  '../data\\지역_위치별(주유소) (6).xls',
#  '../data\\지역_위치별(주유소) (7).xls',
#  '../data\\지역_위치별(주유소) (8).xls',
#  '../data\\지역_위치별(주유소) (9).xls',
#  '../data\\지역_위치별(주유소).xls']

# %%
tmp_raw = []

for file_name in station_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 508 entries, 0 to 41
# Data columns (total 10 columns):
# 지역       508 non-null object
# 상호       508 non-null object
# 주소       508 non-null object
# 상표       508 non-null object
# 전화번호     508 non-null object
# 셀프여부     508 non-null object
# 고급휘발유    508 non-null object
# 휘발유      508 non-null object
# 경유       508 non-null object
# 실내등유     508 non-null object
# dtypes: object(10)
# memory usage: 43.7+ KB

# %%
station_raw.head()
# Out:
#       지역                상호                          주소      상표         전화번호  \
# 0  서울특별시            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)   GS칼텍스  02-426-5372
# 1  서울특별시            구천면주유소       서울 강동구 구천면로 357 (암사동)  현대오일뱅크  02-441-0536
# 2  서울특별시  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)   SK에너지  02-484-6165
# 3  서울특별시           방아다리주유소        서울 강동구 동남로 811 (명일동)   SK에너지  02-442-5145
# 4  서울특별시    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)   GS칼텍스  02-475-2600
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    Y     -  1378  1280     -
# 1    N     -  1387  1286     -
# 2    N     -  1397  1297  1131
# 3    Y     -  1398  1298  1040
# 4    N  1716  1399  1299  1050

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'],
                        '주소':station_raw['주소'],
                        '가격':station_raw['휘발유'],
                        '셀프':station_raw['셀프여부'],
                        '상표':station_raw['상표']})

stations.head()
# Out:
#           Oil_store                          주소    가격 셀프      상표
# 0            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)  1378  Y   GS칼텍스
# 1            구천면주유소       서울 강동구 구천면로 357 (암사동)  1387  N  현대오일뱅크
# 2  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)  1397  N   SK에너지
# 3           방아다리주유소        서울 강동구 동남로 811 (명일동)  1398  Y   SK에너지
# 4    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)  1399  N   GS칼텍스

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#           Oil_store                          주소    가격 셀프      상표    구
# 0            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)  1378  Y   GS칼텍스  강동구
# 1            구천면주유소       서울 강동구 구천면로 357 (암사동)  1387  N  현대오일뱅크  강동구
# 2  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)  1397  N   SK에너지  강동구
# 3           방아다리주유소        서울 강동구 동남로 811 (명일동)  1398  Y   SK에너지  강동구
# 4    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)  1399  N   GS칼텍스  강동구

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '특별시', '강남구'],
#       dtype=object)

# %%
stations[stations['구']=='특별시']
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations.loc[stations['구']=='특별시', '구'] = '도봉구'
stations[stations['가격']=='-']
# Out:
#          Oil_store                          주소 가격 셀프      상표    구
# 11    (주)승지 염리동주유소        서울 마포구 백범로 126 (염리동)  -  N  현대오일뱅크  마포구
# 12          망원동주유소       서울 마포구 월드컵로 119 (망원동)  -  N   SK에너지  마포구
# 13           서강주유소        서울 마포구 독막로 134 (창전동)  -  N   SK에너지  마포구
# 22   KR누리(주) 종암주유소        서울 성북구 종암로 145 (종암동)  -  N   SK에너지  성북구
# 24           현대주유소      서울 양천구 남부순환로 372 (신월동)  -  Y   S-OIL  양천구
# 17    대성산업(주)대성주유소        서울 은평구 통일로 642 (녹번동)  -  N   GS칼텍스  은평구
# 16  씨제이대한통운(주)서울지점  서울특별시 관악구 남부순환로 1515 (신림동)  -  N   GS칼텍스  관악구
# 40           동우주유소   서울특별시 강남구  봉은사로 311 (논현동)  -  N   SK에너지  강남구
# 41           삼성주유소        서울 강남구 삼성로 521 (삼성동)  -  N   SK에너지  강남구

# %%
stations = stations[stations['가격'] != '-']
stations
# Out:
#                Oil_store                               주소    가격 셀프      상표  \
# 0                 동서울주유소       서울특별시 강동구  천호대로 1456 (상일동)  1378  Y   GS칼텍스
# 1                 구천면주유소            서울 강동구 구천면로 357 (암사동)  1387  N  현대오일뱅크
# 2       주)지유에너지직영 오렌지주유소         서울특별시 강동구  성안로 102 (성내동)  1397  N   SK에너지
# 3                방아다리주유소             서울 강동구 동남로 811 (명일동)  1398  Y   SK에너지
# 4         GS칼텍스㈜직영 신월주유소           서울 강동구 양재대로 1323 (성내동)  1399  N   GS칼텍스
# 5        (주)퍼스트오일 코알라주유소        서울특별시 강동구  올림픽로 556 (성내동)  1418  Y   S-OIL
# 13  동대문구
# ..   ...
# 10   강남구
# 11   강남구
# 12   강남구
# 13   강남구
# 14   강남구
# 15   강남구
# 16   강남구
# 17   강남구
# 18   강남구
# 19   강남구
# 20   강남구
# 21   강남구
# 22   강남구
# 23   강남구
# 24   강남구
# 25   강남구
# 26   강남구
# 27   강남구
# 28   강남구
# 29   강남구
# 30   강남구
# 31   강남구
# 32   강남구
# 33   강남구
# 34   강남구
# 35   강남구
# 36   강남구
# 37   강남구
# 38   강남구
# 39   강남구
#
# [499 rows x 6 columns]

# %%
stations['가격'] = [float(value) for value in stations['가격']]

# %%
stations.reset_index(inplace=True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 6 columns):
# Oil_store    499 non-null object
# 주소           499 non-null object
# 가격           499 non-null float64
# 셀프           499 non-null object
# 상표           499 non-null object
# 구            499 non-null object
# dtypes: float64(1), object(5)
# memory usage: 23.5+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "C:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
stations.boxplot(column='가격', by='셀프', figsize=(12, 8));

# %%
plt.figure(figsize=(12, 8))

sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, palette="Set3")
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.boxplot(x="상표", y="가격", data=stations, palette="Set3")
sns.swarmplot(x="상표", y="가격", data=stations, color=".6")
plt.show()

# %%
#서울시 구별 주유 가격은?

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
stations.sort_values(by="가격", ascending=False).head(10)
# Out:
#            Oil_store                        주소      가격 셀프     상표    구
# 306            서남주유소      서울 중구 통일로 30 (봉래동1가)  2093.0  N  SK에너지   중구
# 498          뉴서울(강남)      서울 강남구 언주로 716 (논현동)  2028.0  N  SK에너지  강남구
# 113            양재주유소     서울 서초구 바우뫼로 178 (양재동)  1999.0  N  SK에너지  서초구
# 305            장충주유소    서울 중구 장충단로 202 (장충동1가)  1999.0  N  SK에너지   중구
# 152            삼선주유소          서울 성북구  창경궁로 324  1998.0  N  S-OIL  성북구
# 304            필동주유소  서울특별시 중구  퇴계로 196 (필동2가)  1989.0  N  GS칼텍스   중구
# 268             에너비스      서울 용산구 한남대로 82 (한남동)  1978.0  N  SK에너지  용산구
# 293   (주)대양씨앤씨 사직주유소       서울 종로구 사직로 65 (사직동)  1978.0  N  GS칼텍스  종로구
# 294  (주)중앙에너비스 혜화주유소    서울 종로구 창경궁로35길 1 (혜화동)  1978.0  N  SK에너지  종로구
# 267             한남지점    서울 용산구 한남대로21길 4 (한남동)  1978.0  N  SK에너지  용산구

# %%
stations.sort_values(by="가격", ascending=True).head(10)
# Out:
#              Oil_store                         주소      가격 셀프      상표    구
# 307     (주)자연에너지 대창주유소       서울 중랑구 동일로 636 (면목동)  1307.0  N  현대오일뱅크  중랑구
# 241             수유동주유소   서울특별시 강북구  도봉로 395 (수유동)  1314.0  Y   GS칼텍스  강북구
# 270  (주)명연에너지 수색훼미리주유소       서울 은평구 수색로 236 (수색동)  1315.0  Y  현대오일뱅크  은평구
# 269             타이거주유소       서울 은평구 수색로 188 (증산동)  1315.0  Y   SK에너지  은평구
# 131              원천주유소  서울특별시 성북구  돌곶이로 142 (장위동)  1315.0  N   알뜰주유소  성북구
# 308  에스오일(주) 구도일주유소 동천   서울특별시 중랑구  동일로 654 (면목동)  1317.0  Y   S-OIL  중랑구
# 242           북서울고속주유소    서울특별시 강북구 삼양로 410 (수유동)  1317.0  Y   S-OIL  강북구
# 243              에덴주유소        서울 강북구 월계로 195 (번동)  1318.0  Y   SK에너지  강북구
# 441   SK네트웍스(주)도봉행복주유소      서울 도봉구  도봉로 941 (도봉동)  1319.0  Y   SK에너지  도봉구
# 426              월계주유소       서울 노원구 월계로 252 (월계동)  1319.0  Y   GS칼텍스  노원구

# %%
import numpy as np
gu_data = pd.pivot_table(stations, index = ['구'], values=["가격"], aggfunc=np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 강남구  1612.700000
# 강동구  1475.937500
# 강북구  1344.076923
# 강서구  1391.085714
# 관악구  1400.875000

# %%
geo_path = "../data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502, 126.982], zoom_start=10.5, tiles = 'Stamen Toner')
map.choropleth(geo_data = geo_str, data = gu_data, columns=[gu_data.index, '가격'], fill_color='PuRd', key_on='feature.id')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#            Oil_store                        주소      가격 셀프     상표    구
# 306            서남주유소      서울 중구 통일로 30 (봉래동1가)  2093.0  N  SK에너지   중구
# 498          뉴서울(강남)      서울 강남구 언주로 716 (논현동)  2028.0  N  SK에너지  강남구
# 113            양재주유소     서울 서초구 바우뫼로 178 (양재동)  1999.0  N  SK에너지  서초구
# 305            장충주유소    서울 중구 장충단로 202 (장충동1가)  1999.0  N  SK에너지   중구
# 152            삼선주유소          서울 성북구  창경궁로 324  1998.0  N  S-OIL  성북구
# 304            필동주유소  서울특별시 중구  퇴계로 196 (필동2가)  1989.0  N  GS칼텍스   중구
# 268             에너비스      서울 용산구 한남대로 82 (한남동)  1978.0  N  SK에너지  용산구
# 293   (주)대양씨앤씨 사직주유소       서울 종로구 사직로 65 (사직동)  1978.0  N  GS칼텍스  종로구
# 294  (주)중앙에너비스 혜화주유소    서울 종로구 창경궁로35길 1 (혜화동)  1978.0  N  SK에너지  종로구
# 267             한남지점    서울 용산구 한남대로21길 4 (한남동)  1978.0  N  SK에너지  용산구

# %%
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)
oil_price_bottom10
# Out:
#              Oil_store                         주소      가격 셀프      상표    구
# 307     (주)자연에너지 대창주유소       서울 중랑구 동일로 636 (면목동)  1307.0  N  현대오일뱅크  중랑구
# 241             수유동주유소   서울특별시 강북구  도봉로 395 (수유동)  1314.0  Y   GS칼텍스  강북구
# 270  (주)명연에너지 수색훼미리주유소       서울 은평구 수색로 236 (수색동)  1315.0  Y  현대오일뱅크  은평구
# 269             타이거주유소       서울 은평구 수색로 188 (증산동)  1315.0  Y   SK에너지  은평구
# 131              원천주유소  서울특별시 성북구  돌곶이로 142 (장위동)  1315.0  N   알뜰주유소  성북구
# 308  에스오일(주) 구도일주유소 동천   서울특별시 중랑구  동일로 654 (면목동)  1317.0  Y   S-OIL  중랑구
# 242           북서울고속주유소    서울특별시 강북구 삼양로 410 (수유동)  1317.0  Y   S-OIL  강북구
# 243              에덴주유소        서울 강북구 월계로 195 (번동)  1318.0  Y   SK에너지  강북구
# 441   SK네트웍스(주)도봉행복주유소      서울 도봉구  도봉로 941 (도봉동)  1319.0  Y   SK에너지  도봉구
# 426              월계주유소       서울 노원구 월계로 252 (월계동)  1319.0  Y   GS칼텍스  노원구

# %%
gmap_key = "AIzaSyC0Eb83SUaNDnZNIeMhE2pCUBms-AkyfJw"
gmaps = googlemaps.Client(key=gmap_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
